# %%
import numpy as np
import pandas as pd
import scipy
import re
import os
from pathlib import Path

# %% [markdown]
# From Dataset S2 of https://doi.org/10.1073/pnas.2420092122

# %%
df = pd.read_excel('../data/260513_aggregate_corpora/pnas.2420092122.sd02.xlsx', header=2)

# %%
df['doi'] = df['doi'].str.lower()

# %%
df['notes'] = df['set']

# %%
df['source'] = 'aggregate_corpora'

# %%
df = df[['source', 'doi', 'notes']].copy()

# %%
file_prefix = '260513_aggregate_corpora'
df.to_csv('../data/' + file_prefix + '.csv', index=False)
#df_all_slice.to_parquet('../data/' + file_prefix + '.parquet')
# Out:
#                   source                         doi          notes
# 0      aggregate_corpora     10.1002/1878-0261.12603  rw_paper_mill
# 1      aggregate_corpora     10.1002/2211-5463.12032  rw_paper_mill
# 2      aggregate_corpora     10.1002/2211-5463.12139  rw_paper_mill
# 3      aggregate_corpora     10.1002/2211-5463.12142  rw_paper_mill
# 4      aggregate_corpora     10.1002/2211-5463.12204  rw_paper_mill
# ...                  ...                         ...            ...
# 39752  aggregate_corpora        10.1155/2022/1616401   pps_tortured
# 39753  aggregate_corpora  10.1016/j.mcat.2020.110844   pps_tortured
# 39754  aggregate_corpora         10.2298/abs1304447h   pps_tortured
# 39755  aggregate_corpora    10.3389/fncom.2014.00030   pps_tortured
# 39756  aggregate_corpora  10.1016/j.jssc.2020.121430   pps_tortured
#
# [39757 rows x 3 columns]
